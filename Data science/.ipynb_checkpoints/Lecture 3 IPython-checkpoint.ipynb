# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
import pandas as pd
from pandas import DataFrame, Series
from pandas.tools.plotting import scatter_matrix
import seaborn as sns
sns.set(style='ticks', palette='Set2')
# %matplotlib inline

# %% [markdown]
# # Data sets for Regression
# X1 - basic regression
# X1b - basic regression with some vars uncorrelated
# X2 - quadratic relationship
# X2b - exp relationship
# X7 - binning

# %%
n = 150
X1 = np.random.randn(n)
noise = np.random.randn(n)
beta1 = -1.75
y1 = -3 + np.dot(X1,beta1) + noise
DF1 = pd.DataFrame(np.array([y1,X1]).T)

# adding 3 garbage columns
X1b = np.random.randn(n,4)
y1b = -3 + np.dot(X1b[:,2],beta1) + noise
DF1b = pd.DataFrame(np.append(X1b,y1b.reshape(n,1),1))

#quadratic
X2 = X1**2
y2 = -3 + np.dot(X2,beta1) + noise
DF2 = pd.DataFrame(np.array([y2,X1]).T)

# exponential
X2b = np.exp(X1)
y2b = -3 + np.dot(X2b,beta1) + noise
DF2b = pd.DataFrame(np.array([y2b,X1]).T)

# binning
X7 = 1.0*(X1 > 0)
y7 = -3 + np.dot(X7,beta1) + noise
DF7 = pd.DataFrame(np.array([y7,X1]).T)

# outliers
# y = y1
# y[0]=1000000;

# %% [markdown]
# # We are given data sets creatively named DF1, DF1b, DF2, DF2b and DF7. We have one tool so far: linear regression (fitting a straight line). What should we do? How should we start?

# %%
# Let's look at DF1
DF1
# Out:
#             0         1
# 0   -1.160744 -1.599068
# 1   -4.925704 -0.360965
# 2   -3.749750  0.338755
# 3   -0.281485 -1.619345
# 4   -2.935537 -0.702025
# 5   -3.146602 -0.442435
# 6   -6.159431  0.545963
# 7   -1.875215  0.124631
# 8   -5.680136  1.899785
# 9   -0.328928 -1.114393
# 10  -5.448118  0.141641
# 11  -3.883428 -0.240562
# 12  -0.354863 -0.587451
# 13  -4.368454 -0.092842
# 14  -3.674093  1.061184
# 15  -0.189932 -1.410902
# 16  -2.104469 -1.088163
# 17  -2.379834 -0.509012
# 18  -5.588337  1.075997
# 19  -0.469757 -1.058577
# 20  -2.795726 -0.476383
# 21  -3.776775 -0.518686
# 22  -3.738264  0.575885
# 23  -1.158853 -0.488345
# 24  -2.873444 -0.061679
# 25  -4.596644  1.237791
# 26  -0.730293  0.537657
# 27  -3.409783  0.676890
# 28  -1.763892  0.142220
# 29  -4.483394  1.155917
# ..        ...       ...
# 120 -2.973705 -0.052540
# 121 -5.348936  0.968743
# 122 -2.200438  0.020413
# 123 -0.192332 -0.730118
# 124 -1.075382 -0.852066
# 125 -6.619873  1.531787
# 126 -2.994230 -0.236776
# 127 -1.432113 -1.140924
# 128 -3.170739  0.279609
# 129 -0.916196 -0.819096
# 130 -0.079815 -0.777995
# 131  0.323553 -0.563419
# 132  1.923500 -2.774515
# 133 -4.908137  1.235925
# 134  0.526590 -1.908143
# 135 -5.530982  0.567286
# 136 -4.863420  1.165149
# 137 -1.342825 -0.242713
# 138 -3.064416  0.321810
# 139  0.805409 -1.426243
# 140 -2.838092 -0.305304
# 141 -2.201103  0.236941
# 142 -4.146994  0.821186
# 143 -5.461135  1.144610
# 144 -1.182371 -1.253951
# 145 -7.889316  1.189699
# 146  0.649539 -1.554095
# 147 -0.714772 -0.708236
# 148 -0.412581 -0.439536
# 149 -2.408498 -0.355957
#
# [150 rows x 2 columns]

# %%
# Maybe not too helpful. Let's look at it.
scatter_matrix(DF1)
sns.despine()

# %%
# Seems promising! Let's do a linear fit
lr = linear_model.LinearRegression()
lr.fit(X1.reshape(-1,1),y1)
# These are the coefficients we found.
print lr.coef_, lr.intercept_
# Out:
# [-1.81060203] -2.92279645315

# %%
# And we can plot the fit again:
plt.scatter(X1.reshape(-1,1),y1,  color='black')
plt.plot(X1.reshape(-1.1), lr.predict(X1.reshape(-1,1)), color='blue',
         linewidth=3)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   app.launch_new_instance()

# %%
# Ok that was easy... Now let's look at DF1b. What to do?
DF1b
# Out:
#             0         1         2         3         4
# 0   -0.309436  0.293088 -0.486415  0.826505 -3.107887
# 1    1.098987 -0.559538 -0.169709 -0.840941 -5.260403
# 2    0.966101  0.380278  0.081159 -0.346769 -3.298957
# 3    0.412483 -1.665098 -1.529491 -0.362258 -0.438729
# 4    1.558621 -0.641295 -1.114639 -1.001144 -2.213464
# 5    0.588846 -0.626322  0.450629  0.810036 -4.709463
# 6   -1.445053 -0.448358 -0.644198 -0.565944 -4.076649
# 7    0.412579  0.446449  2.038981 -1.220501 -5.225328
# 8   -0.111214 -0.772422  0.768934  0.629634 -3.701147
# 9   -1.485787  0.300441  0.030086 -1.355783 -2.331765
# 10  -0.697718  0.016721 -0.005607 -0.609416 -5.190433
# 11  -1.756272 -0.339029  0.855272 -0.858877 -5.801137
# 12  -0.051128  0.990627  1.049626 -0.777190 -3.219747
# 13  -0.254617  0.271467  2.642654  0.008697 -9.155572
# 14  -0.747721 -0.305756  1.260728 -1.228338 -4.023296
# 15  -2.408858  0.932243 -0.624146 -2.539521 -1.566755
# 16   2.028927  1.168435  0.307216  0.434789 -4.546382
# 17   0.758967 -0.414146  0.801306 -0.063769 -4.672891
# 18   1.293886 -0.049877 -1.851176  0.003621 -0.465784
# 19  -0.143571 -0.972823 -0.607769  0.653414 -1.258672
# 20  -1.797971 -1.767325 -1.897273 -0.009252 -0.309169
# 21   0.169428 -0.837912  0.532089  0.441149 -5.615631
# 22  -1.005899  0.290877  0.619029 -1.260220 -3.813765
# 23  -1.025749  0.018603  0.931794 -1.369504 -3.644097
# 24  -0.491697  0.178586 -0.201548 -1.813045 -2.628673
# 25  -0.926233 -0.230225 -1.030688 -0.133945 -0.626807
# 26   0.796484  1.364093  0.019234 -0.284335  0.176946
# 27  -1.000534 -1.206140  0.876496 -0.979857 -3.759094
# 28   0.089425 -1.363821 -1.554078 -0.182307  1.204629
# 29  -0.511710  0.956452  1.283803  0.546764 -4.707196
# ..        ...       ...       ...       ...       ...
# 120  0.810817  0.127389 -0.827469  0.823172 -1.617579
# 121  1.557709 -0.255720 -0.005799  0.647521 -3.643486
# 122 -0.658752  0.328398  0.503417 -1.463016 -3.045695
# 123  0.233259  1.824045 -0.238697  0.229526 -1.052320
# 124  1.459070 -1.230894  0.693146 -0.425658 -3.779505
# 125 -0.280621  0.445073  0.273070  0.704816 -4.417118
# 126 -0.088220 -1.913481  1.824312 -0.510846 -6.601135
# 127  1.233146  0.186759 -0.447516 -2.604743 -2.645578
# 128  0.889283 -0.365514 -0.266216  0.326473 -2.215546
# 129 -0.562208  1.148946  0.286640  1.032144 -2.851233
# 130 -0.050624 -0.207293  0.326381  1.769450 -2.012473
# 131  0.574405  0.078805 -0.561445  0.015718  0.320099
# 132  0.294614  0.864733  0.465286 -0.280409 -3.746152
# 133 -0.675022  0.329551 -0.530194 -1.232102 -1.817429
# 134 -0.187291  1.018515 -0.335056 -1.239843 -2.226312
# 135  0.056481 -0.484822 -0.565175 -1.742301 -3.549175
# 136 -0.184362 -1.192123  0.091140  1.067152 -2.983905
# 137 -0.160922 -0.027869  1.558297 -0.295770 -4.494591
# 138 -1.946879  0.781232 -0.558844  1.470105 -1.523271
# 139 -1.699219  0.966137  0.392454 -1.685363 -2.377310
# 140 -0.587127 -1.384185 -0.008760  0.737591 -3.357045
# 141  0.841933 -0.984280  1.151777 -0.010213 -3.802066
# 142  0.336155  0.608122  0.280470 -0.691856 -3.200740
# 143  0.469954  1.500480 -2.137470 -1.249631  0.282504
# 144 -0.141869 -0.614718  1.207911  2.113747 -5.490629
# 145 -0.921426 -1.014451 -0.197471  0.876537 -5.461767
# 146  0.689707 -0.265318  0.018527 -0.302621 -2.102551
# 147 -0.825348  0.848368 -0.035251 -0.886694 -1.892495
# 148  1.421516 -0.266128 -0.177137  1.092986 -0.871778
# 149  1.314349 -0.016613  2.496382 -1.267508 -7.400092
#
# [150 rows x 5 columns]

# %% [markdown]
# # Let's look at this one too. But how?

# %%
scatter_matrix(DF1b)
sns.despine()

# %% [markdown]
# # What happens if we try to find a relationship between y and the first column?

# %%
lr = linear_model.LinearRegression()
lr.fit(X1b[:,0].reshape(-1,1),y1)
# These are the coefficients we found.
print lr.coef_, lr.intercept_
# Out:
# [ 0.06581439] -2.80844587627

# %%
# And we can plot the fit again:
plt.scatter(X1b[:,0].reshape(-1,1),y1,  color='black')
plt.plot(X1b[:,0].reshape(-1.1), lr.predict(X1b[:,0].reshape(-1,1)), color='blue',
         linewidth=3)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   app.launch_new_instance()

# %% [markdown]
# # What are this plot and the values telling us? (Nothing...)

# %% [markdown]
# # On to the next thing...

# %%
scatter_matrix(DF2)
sns.despine()

# %% [markdown]
# # Things look less promising... let's try to do linear regression anyway.

# %%
lr = linear_model.LinearRegression()
lr.fit(X1.reshape(-1,1),y2)
# These are the coefficients we found.
print lr.coef_, lr.intercept_
# And we can plot the fit again:
plt.scatter(X1.reshape(-1,1),y2,  color='black')
plt.plot(X1.reshape(-1.1), lr.predict(X1.reshape(-1,1)), color='blue',
         linewidth=3)
# Out:
# [-0.20339663] -4.69382139232
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
lr = linear_model.LinearRegression()
lr.fit(X1.reshape(-1,1),y2b)
# These are the coefficients we found.
print lr.coef_, lr.intercept_
# And we can plot the fit again:
plt.scatter(X1.reshape(-1,1),y2b,  color='black')
plt.plot(X1.reshape(-1,1), lr.predict(X1.reshape(-1,1)), color='blue',
         linewidth=3)
# Out:
# [-2.78111673] -5.81402443701
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# # Ideas for what we could do instead?

# %%
# The first plot looks more like a quadratic. Let's try that by transforming the data by the square:
Z = X1**2
lr = linear_model.LinearRegression()
lr.fit(Z.reshape(-1,1),y2)
# These are the coefficients we found.
print lr.coef_, lr.intercept_
# And we can plot the fit again:
plt.scatter(Z.reshape(-1,1),y2,  color='black')
plt.plot(Z.reshape(-1,1), lr.predict(Z.reshape(-1,1)), color='blue',
         linewidth=3)
# Out:
# [-1.83106577] -2.98521908967
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# # These things happen in real data sets. Example: Predicting Fuel Efficiency

# %%
# A car data set -- Fuel Efficiency Data
# First we load the data
data = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data-original",
                   delim_whitespace = True, header=None,
                   names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration',
                            'model', 'origin', 'car_name'])
data = data.dropna()
sns.pairplot(data)

# %%
sns.lmplot("mpg", "weight", data, order=1);

# %%
sns.lmplot("mpg", "weight", data, order=2);

# %% [markdown]
# # What do we do when we cannot visualize?

# %%
# Skewness: 
print compute_skewness(X1)
print compute_skewness(X2)
print compute_skewness(X2b)
# Out:
# -0.0307655581373
# 1.92891416696
# 2.43774286185

# %% [markdown]
# # Next!

# %%
scatter_matrix(DF7)
sns.despine()

# %%
lr = linear_model.LinearRegression()
lr.fit(X1.reshape(-1,1),y7)
# These are the coefficients we found.
print lr.coef_, lr.intercept_
# And we can plot the fit again:
plt.scatter(X1.reshape(-1,1),y7,  color='black')
plt.plot(X1.reshape(-1,1), lr.predict(X1.reshape(-1,1)), color='blue',
         linewidth=3)
# Out:
# [-0.83474697] -3.91776708342

# %%
lr = linear_model.LinearRegression()
lr.fit(X7.reshape(-1,1),y7)
# These are the coefficients we found.
print lr.coef_, lr.intercept_
# And we can plot the fit again:
plt.scatter(X1.reshape(-1,1),y7,  color='black')
plt.plot(X1.reshape(-1,1), lr.predict(X1.reshape(-1,1)), color='blue',
         linewidth=3)
# Out:
# [-1.92128119] -2.94097143383

# %%
lr = linear_model.LinearRegression()
lr.fit(X7.reshape(-1,1),y7)
# These are the coefficients we found.
print lr.coef_, lr.intercept_
# And we can plot the fit again:
plt.scatter(X7.reshape(-1,1),y7,  color='black')
plt.plot(X7.reshape(-1,1), lr.predict(X7.reshape(-1,1)), color='blue',
         linewidth=3)
# Out:
# [-1.92128119] -2.94097143383

# %%
def compute_skewness(x):
    n = x.shape[0]
    xbar = np.mean(x)
    v = np.mean((x - xbar)**2)*(n/(n-1))
    skew = np.mean((x-xbar)**3)*(n/(n-1))*(v**(-1.5))
    return skew

# %%
# Back to Simple Regression
lr = linear_model.LinearRegression()
lr.fit(X1.reshape(-1,1),y)
# These are the coefficients we found.
print lr.coef_, lr.intercept_
plt.scatter(X1[1:].reshape(-1,1),y[1:],  color='black')
plt.plot(X1[1:].reshape(-1,1), lr.predict(X1[1:].reshape(-1,1)), color='blue',
         linewidth=3)
# Out:
# [-1282.36929501] 6631.45476879

# %% [markdown]
# # ???
